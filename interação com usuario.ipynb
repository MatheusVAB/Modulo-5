# %% [markdown]
# # Visualização de variáveis e textos

# %%
print("Conhecendo o comando Print")

x = 8
print(x)
# Out:
# Conhecendo o comando Print
# 8

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = 'Matheus Borges'
print(nome)
# Out:
# Matheus Borges

# %% [markdown]
# **Concatenação**

# %%
x = 5
print('O valor de x é', x)

print('O valor de x é', x, 'e o dobro é', x * 2)

print('Eu,', nome, 'tirei', x, 'na prova de Python')
y = 10; z = 20 + x - y
print('Declarar várias variáveis na mesma linha:', y, z)
# Out:
# O valor de x é 5
# O valor de x é 5 e o dobro é 10
# Eu, Matheus Borges tirei 5 na prova de Python
# Declarar várias variáveis na mesma linha: 10 15

# %% [markdown]
# **Type**

# %%
x = 10
type(x)
print('x', type(x))
nome = 'Matheus'
print('nome', type(nome))
num = '100'
num_convert = int(num)  # Converter variável
print('num', type(num))
print('num_convert', type(num_convert))
num_float = float(num)
print('num_float', type(num_float), num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_convert <class 'int'>
# num_float <class 'float'> 100.0

# %% [markdown]
# **Imput**
#
#
# *   Armazenar a informação digitada pelo usuario em uma variavel
# *   O dado armazenado sempre será um texto

# %%
nome = input('Digite o nome do usuário: ')  # Aguarda o usuário digitar algo
print(nome)
# Out:
# Digite o nome do usuário: Matheus
# Matheus

# %%
valor = input('Digite a nota: ')
print(nome, 'sua nota foi', valor)
# Out:
# Digite a nota: 8
# Matheus sua nota foi 8

# %%
valor = input('Digite o valor do produto: ')
print(valor)
# Out:
# Digite o valor do produto: 100
# 100

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-19-3009817088.py in <cell line: 0>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
# Convertendo string para número antes de subtrair
valor_convert = int(valor)
desconto = valor_convert - 5
print(desconto)
# Out:
# 95

# %%
desconto = int(valor) - 5
print(desconto)
# Out:
# 95
