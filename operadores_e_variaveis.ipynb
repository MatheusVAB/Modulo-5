# %% [markdown]
# # Operadores Aritiméticos

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão inteira
10 // 2
# Out:
# 5

# %%
# Resto da divisão
10 % 2
# Out:
# 0

# %%
# Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# # Operadores Racionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Diferente
7 != 7
# Out:
# False

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# *   And
# *   Or
# *   Not

# %% [markdown]
# # Tabela Verdade

# %% [markdown]
# And

# %%
[]
print(10 > 2 and 4 < 6)
print(10 > 2 and 4 > 6)
print(10 < 2 and 4 < 6)
print(10 < 2 and 4 > 6)
# Out:
# True
# False
# False
# False

# %% [markdown]
# Or

# %%
[]
print(10 > 2 or 4 < 6)
print(10 > 2 or 4 > 6)
print(10 < 2 or 4 < 6)
print(10 < 2 or 4 > 6)
# Out:
# True
# True
# True
# False

# %% [markdown]
# Not

# %%
print(not 10 > 2)
# Out:
# False

# %%
print(not 10 < 2)
# Out:
# True

# %% [markdown]
# # Variáveis

# %% [markdown]
# Variáveis estao alocadas em espaços na memória

# %%
# Nome da variável é "x" que armazena o valor 10 na memória
x = 10

print(x) # Utilizar a referencia do nome atribuido
# Out:
# 10

# %% [markdown]
# Regras

# %% [markdown]
#  **Case** **sensitive**

# %% [markdown]
# A != a

# %% [markdown]
# **Boas praticas com variáveis**

# %% [markdown]
#   Exemplo: multiplicação de dois numeros
#
# Nao usar:
#
# *   Multiplicação
# *   MultiplicacaoDeDoisNumeros
# *   m
#
# Usar:
#
# * multiplicacao
# * mult
# * mult_total (snake_case)

# %% [markdown]
# Tipos de variaveis

# %% [markdown]
#     Pyton é uma linguagem de alto nivel
